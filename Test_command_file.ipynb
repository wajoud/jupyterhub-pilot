# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jupyterhub_pilot-ai
#   Downloading jupyterhub_pilot_ai-0.3.0-py3-none-any.whl (7.8 kB)
# Collecting ipython
#   Downloading ipython-8.18.1-py3-none-any.whl (808 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.2/808.2 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from jupyterhub_pilot-ai) (2.28.1)
# Collecting litellm
#   Downloading litellm-1.83.9-py3-none-any.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 16.3 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.2.2-py3-none-any.whl (9.5 kB)
# Collecting pygments>=2.4.0
#   Using cached pygments-2.20.0-py3-none-any.whl (1.2 MB)
# Collecting traitlets>=5
#   Downloading traitlets-5.15.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 6.1 MB/s eta 0:00:00
# Collecting pexpect>4.3
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.8 MB/s eta 0:00:00
# Collecting stack-data
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.4/391.4 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterhub_pilot-ai) (4.12.2)
# Collecting decorator
#   Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: exceptiongroup in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterhub_pilot-ai) (1.1.1)
# Collecting jedi>=0.16
#   Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.4 MB/s eta 0:00:00
# Collecting aiohttp==3.13.3
#   Downloading aiohttp-3.13.3-cp39-cp39-macosx_11_0_arm64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.4/492.4 kB 16.8 MB/s eta 0:00:00
# Collecting pydantic==2.12.5
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 20.0 MB/s eta 0:00:00
# Collecting jinja2==3.1.6
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting jsonschema==4.23.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 9.6 MB/s eta 0:00:00
# Collecting tiktoken==0.12.0
#   Downloading tiktoken-0.12.0-cp39-cp39-macosx_11_0_arm64.whl (997 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.1/997.1 kB 25.9 MB/s eta 0:00:00
# Collecting httpx==0.28.1
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting click==8.1.8
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting fastuuid==0.14.0
#   Downloading fastuuid-0.14.0-cp39-cp39-macosx_11_0_arm64.whl (256 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.4/256.4 kB 10.2 MB/s eta 0:00:00
# Collecting importlib-metadata==8.5.0
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Collecting tokenizers==0.22.2
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 24.6 MB/s eta 0:00:00a 0:00:01
# Collecting openai==2.24.0
#   Downloading openai-2.24.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.7 MB/s eta 0:00:00
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 5.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp39-cp39-macosx_11_0_arm64.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.1 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.22.0-cp39-cp39-macosx_11_0_arm64.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 9.5 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp39-cp39-macosx_11_0_arm64.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.2 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting aiosignal>=1.4.0
#   Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.4.1-cp39-cp39-macosx_11_0_arm64.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from httpx==0.28.1->litellm->jupyterhub_pilot-ai) (2022.9.24)
# Requirement already satisfied: idna in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from httpx==0.28.1->litellm->jupyterhub_pilot-ai) (3.4)
# Requirement already satisfied: anyio in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from httpx==0.28.1->litellm->jupyterhub_pilot-ai) (3.6.2)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from jinja2==3.1.6->litellm->jupyterhub_pilot-ai) (2.1.1)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.27.1-cp39-cp39-macosx_11_0_arm64.whl (354 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.1/354.1 kB 13.2 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: sniffio in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from openai==2.24.0->litellm->jupyterhub_pilot-ai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from openai==2.24.0->litellm->jupyterhub_pilot-ai) (4.31.1)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.14.0-cp39-cp39-macosx_11_0_arm64.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.3/315.3 kB 8.9 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.1 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting regex>=2022.1.18
#   Downloading regex-2026.1.15-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.5/288.5 kB 10.1 MB/s eta 0:00:00
# Collecting huggingface-hub<2.0,>=0.16.4
#   Downloading huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.2/625.2 kB 19.7 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from requests->jupyterhub_pilot-ai) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from requests->jupyterhub_pilot-ai) (2.1.1)
# Collecting parso<0.9.0,>=0.8.4
#   Downloading parso-0.8.7-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 9.1 MB/s eta 0:00:00
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.7.0-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 5.7 MB/s eta 0:00:00
# Collecting asttokens>=2.1.0
#   Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Collecting executing>=1.2.0
#   Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Collecting tqdm>4
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.0 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.4.2
#   Downloading hf_xet-1.5.0-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 23.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock>=3.10.0 in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers==0.22.2->litellm->jupyterhub_pilot-ai) (3.11.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 10.0 MB/s eta 0:00:00
# Collecting typer
#   Downloading typer-0.23.2-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /Users/wajoud/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers==0.22.2->litellm->jupyterhub_pilot-ai) (23.0)
# Collecting pyyaml>=5.1
#   Downloading pyyaml-6.0.3-cp39-cp39-macosx_11_0_arm64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 9.4 MB/s eta 0:00:00
# Collecting annotated-doc>=0.0.2
#   Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=12.3.0
#   Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pure-eval, ptyprocess, zipp, wcwidth, typing-extensions, traitlets, tqdm, shellingham, rpds-py, regex, pyyaml, python-dotenv, pygments, propcache, pexpect, parso, mdurl, jiter, jinja2, hf-xet, h11, fsspec, frozenlist, fastuuid, executing, distro, decorator, click, attrs, async-timeout, asttokens, annotated-types, annotated-doc, aiohappyeyeballs, typing-inspection, tiktoken, stack-data, referencing, pydantic-core, prompt-toolkit, multidict, matplotlib-inline, markdown-it-py, jedi, importlib-metadata, httpcore, aiosignal, yarl, rich, pydantic, jsonschema-specifications, ipython, httpx, typer, openai, jsonschema, aiohttp, huggingface-hub, tokenizers, litellm, jupyterhub_pilot-ai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.31.1
#     Uninstalling tqdm-4.31.1:
#       Successfully uninstalled tqdm-4.31.1
#   WARNING: The script tqdm is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pygmentize is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   WARNING: The script distro is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   WARNING: The script markdown-it is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   WARNING: The scripts ipython and ipython3 are installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script openai is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema is installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf and tiny-agents are installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts litellm and litellm-proxy are installed in '/Users/wajoud/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ximilar-client 1.21.8 requires requests==2.21.0, but you have requests 2.28.1 which is incompatible.
# ximilar-client 1.21.8 requires tqdm==4.31.1, but you have tqdm 4.67.3 which is incompatible.
# fastapi 0.88.0 requires pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2, but you have pydantic 2.12.5 which is incompatible.
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-doc-0.0.4 annotated-types-0.7.0 asttokens-3.0.1 async-timeout-5.0.1 attrs-26.1.0 click-8.1.8 decorator-5.2.1 distro-1.9.0 executing-2.2.1 fastuuid-0.14.0 frozenlist-1.8.0 fsspec-2025.10.0 h11-0.16.0 hf-xet-1.5.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.8.0 importlib-metadata-8.5.0 ipython-8.18.1 jedi-0.19.2 jinja2-3.1.6 jiter-0.14.0 jsonschema-4.23.0 jsonschema-specifications-2025.9.1 jupyterhub_pilot-ai-0.3.0 litellm-1.83.9 markdown-it-py-3.0.0 matplotlib-inline-0.2.2 mdurl-0.1.2 multidict-6.7.1 openai-2.24.0 parso-0.8.7 pexpect-4.9.0 prompt-toolkit-3.0.52 propcache-0.4.1 ptyprocess-0.7.0 pure-eval-0.2.3 pydantic-2.12.5 pydantic-core-2.41.5 pygments-2.20.0 python-dotenv-1.0.1 pyyaml-6.0.3 referencing-0.36.2 regex-2026.1.15 rich-15.0.0 rpds-py-0.27.1 shellingham-1.5.4 stack-data-0.6.3 tiktoken-0.12.0 tokenizers-0.22.2 tqdm-4.67.3 traitlets-5.15.0 typer-0.23.2 typing-extensions-4.15.0 typing-inspection-0.4.2 wcwidth-0.7.0 yarl-1.22.0 zipp-3.23.1
#
# [notice] A new release of pip available: 22.2.2 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
# %do create a confusion matrix

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# Example true labels and predicted labels
y_true = [1, 0, 1, 1, 0, 1, 0, 1]
y_pred = [1, 1, 0, 1, 0, 1, 1, 0]

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred)

print(cm)

# %%
from sklearn.metrics import confusion_matrix

# Assuming y_true and y_pred are your true labels and predicted labels respectively
confusion_mat = confusion_matrix(y_true, y_pred)

print(confusion_mat)

# %%
print("Hello World")

# %%
print("Hello World!")

# %%
import plotly.express as px
import numpy as np

# Generate random data
np.random.seed(42)
x = np.random.rand(100)
y = np.random.rand(100)

# Create scatter plot
fig = px.scatter(x=x, y=y, title='Random Data Scatter Plot')
fig.show()

# %%
print(variable_that_doesnt_exist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(variable_that_doesnt_exist)
#
# NameError: name 'variable_that_doesnt_exist' is not defined

# %%
# %fix

# %%
try:
    print(variable_that_doesnt_exist)
except NameError:
    print("Variable does not exist")

# %%
pd.datafram()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.datafram()
#
# NameError: name 'pd' is not defined

# %%
# %fix

# %%
import pandas as pd
df = pd.DataFrame()
